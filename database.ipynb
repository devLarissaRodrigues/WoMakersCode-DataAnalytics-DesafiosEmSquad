# %% [markdown]
# <a href="https://colab.research.google.com/github/devLarissaRodrigues/WoMakersCode-DataAnalytics-Desafio1/blob/Etapa2/database-etapa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Etapa 1 - Incerindo os dados provenientes na pasta WoMakersCode no google drive.

# %% [markdown]
# Acessando a pasta aberta WoMakersCode - Case 7 - Titanic no google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Validando o arquivo .csv.

# %%
# !ls "/content/drive/My Drive/WoMakersCode - Case 7 - Titanic/train.csv"
# Out:
# '/content/drive/My Drive/WoMakersCode - Case 7 - Titanic/train.csv'

# %% [markdown]
# Importando Pandas, Caminho até o arquivo .csv, ler o arquivo e visualizando as 20 primeiras linhas

# %%
import pandas as pd

# Caminho do arquivo (ajuste conforme necessário)
caminho_arquivo = "/content/drive/My Drive/WoMakersCode - Case 7 - Titanic/train.csv"

# Ler o CSV
df = pd.read_csv(caminho_arquivo)

# Visualizar as primeiras linhas
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %% [markdown]
# Mostrando a qualidade dos dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Análise dos Tipos de Dados Atuais
# Com base no df.info(), os tipos de dados atuais são:
#
# int64: PassengerId, Survived, Pclass, SibSp, Parch (parecem corretos)
#
# float64: Age, Fare (também parecem corretos, pois podem ter casas decimais)
#
# object: Name, Sex, Ticket, Cabin, Embarked (precisamos revisar)
#
# N

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cmap="viridis", cbar=False, yticklabels=False)
plt.title("Valores Nulos no Dataset")
plt.show()
